# %%
import pandas as pd

# %%
df=pd.read_csv("https://hub.jovian.ml/wp-content/uploads/2020/09/countries.csv")

# %%
df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita
# 0                          0.50        1803.987
# 1                          2.89       11803.431
# 2                          1.90       13913.839
# 3                           NaN             NaN
# ...

# %% [markdown]
#  dataframe containing 10 countries with the highest population.

# %%
df[["location","population"]].sort_values("population", ascending=False).head(10)
# Out:
#           location    population
# 41           China  1.439324e+09
# 90           India  1.380004e+09
# 199  United States  3.310026e+08
# 91       Indonesia  2.735236e+08
# 145       Pakistan  2.208923e+08
# 27          Brazil  2.125594e+08
# 141        Nigeria  2.061396e+08
# 15      Bangladesh  1.646894e+08
# 157         Russia  1.459345e+08
# 125         Mexico  1.289328e+08

# %% [markdown]
# new column in countries_df to record the overall GDP per country (product of population & per capita GDP).

# %%
df['gdp']=df["population"]*df["gdp_per_capita"]

# %%
df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita           gdp
# 0                          0.50        1803.987  7.022622e+10
# 1                          2.89       11803.431  3.396791e+10
# 2                          1.90       13913.839  6.101364e+11
# ...

# %% [markdown]
# data frame that counts the number countries in each continent

# %%
df.groupby("continent")["location"].count()
# Out:
# continent
# Africa           55
# Asia             47
# Europe           51
# North America    36
# Oceania           8
# South America    13
# Name: location, dtype: int64

# %% [markdown]
# a data frame showing the total population of each continent.

# %%
df.groupby("continent")["population"].sum()
# Out:
# continent
# Africa           1.339424e+09
# Asia             4.607388e+09
# Europe           7.485062e+08
# North America    5.912425e+08
# Oceania          4.095832e+07
# South America    4.304611e+08
# Name: population, dtype: float64

# %% [markdown]
# Importing another csv files

# %%
df1=pd.read_csv("https://hub.jovian.ml/wp-content/uploads/2020/09/covid-countries-data.csv")

# %%
df1
# Out:
#            location  total_cases  total_deaths  total_tests
# 0       Afghanistan      38243.0        1409.0          NaN
# 1           Albania       9728.0         296.0          NaN
# 2           Algeria      45158.0        1525.0          NaN
# 3           Andorra       1199.0          53.0          NaN
# 4            Angola       2729.0         109.0          NaN
# ..              ...          ...           ...          ...
# 207  Western Sahara        766.0           1.0          NaN
# 208           World   26059065.0      863535.0          NaN
# 209           Yemen       1976.0         571.0          NaN
# 210          Zambia      12415.0         292.0          NaN
# 211        Zimbabwe       6638.0         206.0      97272.0
#
# [212 rows x 4 columns]

# %% [markdown]
# Checking total NaN value

# %%
df1.isnull().sum()
# Out:
# location          0
# total_cases       1
# total_deaths      1
# total_tests     122
# dtype: int64

# %% [markdown]
# Checking "total_tests" NaN value

# %%
df1.isna().total_tests.sum()
# Out:
# 122

# %%
df1.isna().total_tests.sum()
# Out:
# 122

# %% [markdown]
# a dataframe with 10 countires that have highest number of tests

# %%
df1[["location","total_tests"]].sort_values("total_tests",ascending=False).head(10)
# Out:
#                  location  total_tests
# 200         United States   83898416.0
# 90                  India   44337201.0
# 158                Russia   37176827.0
# 199        United Kingdom   13447568.0
# 73                Germany   11208091.0
# 194                Turkey    7247935.0
# 198  United Arab Emirates    7177430.0
# 178                 Spain    6416533.0
# 10              Australia    6255797.0
# 35                 Canada    5545473.0

# %% [markdown]
# a dataframe with 10 countires that have highest number of deaths cases

# %%
df1[["location","total_deaths"]].sort_values("total_deaths",ascending=False).head(10)
# Out:
#            location  total_deaths
# 208           World      863535.0
# 200   United States      185744.0
# 27           Brazil      123780.0
# 90            India       67376.0
# 126          Mexico       65816.0
# 199  United Kingdom       41514.0
# 98            Italy       35497.0
# 68           France       30686.0
# 151            Peru       29259.0
# 178           Spain       29194.0

# %%
df1.loc[208]
# Out:
# location              World
# total_cases     2.60591e+07
# total_deaths         863535
# total_tests             NaN
# Name: 208, dtype: object

# %% [markdown]
# a dataframe with 10 countires that have highest number of total_cases

# %%
df1[["location","total_cases"]].sort_values("total_cases",ascending=False).head(10)
# Out:
#           location  total_cases
# 208          World   26059065.0
# 200  United States    6114406.0
# 27          Brazil    3997865.0
# 90           India    3853406.0
# 158         Russia    1005000.0
# 151           Peru     663437.0
# 42        Colombia     633339.0
# 175   South Africa     630595.0
# 126         Mexico     610957.0
# 178          Spain     479554.0

# %% [markdown]
# Merge df1 with df on the location column.

# %%
combined_df= df1.merge(df,on="location")

# %%
combined_df
# Out:
#            location  total_cases  total_deaths  total_tests continent  \
# 0       Afghanistan      38243.0        1409.0          NaN      Asia
# 1           Albania       9728.0         296.0          NaN    Europe
# 2           Algeria      45158.0        1525.0          NaN    Africa
# 3           Andorra       1199.0          53.0          NaN    Europe
# 4            Angola       2729.0         109.0          NaN    Africa
# ..              ...          ...           ...          ...       ...
# 205         Vietnam       1046.0          35.0     261004.0      Asia
# 206  Western Sahara        766.0           1.0          NaN    Africa
# 207           Yemen       1976.0         571.0          NaN      Asia
# 208          Zambia      12415.0         292.0          NaN    Africa
# 209        Zimbabwe       6638.0         206.0      97272.0    Africa
#
#      population  life_expectancy  hospital_beds_per_thousand  gdp_per_capita  \
# ...

# %% [markdown]
# # tests_per_million, cases_per_million and deaths_per_million into combined_df

# %%
combined_df['tests_per_million'] = combined_df['total_tests'] * 1e6 / combined_df['population']

# %%
combined_df
# Out:
#            location  total_cases  total_deaths  total_tests continent  \
# 0       Afghanistan      38243.0        1409.0          NaN      Asia
# 1           Albania       9728.0         296.0          NaN    Europe
# 2           Algeria      45158.0        1525.0          NaN    Africa
# 3           Andorra       1199.0          53.0          NaN    Europe
# 4            Angola       2729.0         109.0          NaN    Africa
# ..              ...          ...           ...          ...       ...
# 205         Vietnam       1046.0          35.0     261004.0      Asia
# 206  Western Sahara        766.0           1.0          NaN    Africa
# 207           Yemen       1976.0         571.0          NaN      Asia
# 208          Zambia      12415.0         292.0          NaN    Africa
# 209        Zimbabwe       6638.0         206.0      97272.0    Africa
#
#      population  life_expectancy  hospital_beds_per_thousand  gdp_per_capita  \
# ...

# %%
combined_df['cases_per_million'] = combined_df['total_cases'] * 1e6 / combined_df['population']

# %%
combined_df
# Out:
#            location  total_cases  total_deaths  total_tests continent  \
# 0       Afghanistan      38243.0        1409.0          NaN      Asia
# 1           Albania       9728.0         296.0          NaN    Europe
# 2           Algeria      45158.0        1525.0          NaN    Africa
# 3           Andorra       1199.0          53.0          NaN    Europe
# 4            Angola       2729.0         109.0          NaN    Africa
# ..              ...          ...           ...          ...       ...
# 205         Vietnam       1046.0          35.0     261004.0      Asia
# 206  Western Sahara        766.0           1.0          NaN    Africa
# 207           Yemen       1976.0         571.0          NaN      Asia
# 208          Zambia      12415.0         292.0          NaN    Africa
# 209        Zimbabwe       6638.0         206.0      97272.0    Africa
#
#      population  life_expectancy  hospital_beds_per_thousand  gdp_per_capita  \
# ...

# %%
combined_df['deaths_per_million']=combined_df['total_deaths'] * 1e6 / combined_df['population']

# %%
combined_df
# Out:
#            location  total_cases  total_deaths  total_tests continent  \
# 0       Afghanistan      38243.0        1409.0          NaN      Asia
# 1           Albania       9728.0         296.0          NaN    Europe
# 2           Algeria      45158.0        1525.0          NaN    Africa
# 3           Andorra       1199.0          53.0          NaN    Europe
# 4            Angola       2729.0         109.0          NaN    Africa
# ..              ...          ...           ...          ...       ...
# 205         Vietnam       1046.0          35.0     261004.0      Asia
# 206  Western Sahara        766.0           1.0          NaN    Africa
# 207           Yemen       1976.0         571.0          NaN      Asia
# 208          Zambia      12415.0         292.0          NaN    Africa
# 209        Zimbabwe       6638.0         206.0      97272.0    Africa
#
#      population  life_expectancy  hospital_beds_per_thousand  gdp_per_capita  \
# ...

# %%
highest_cases_df=combined_df[["location","cases_per_million"]].sort_values("cases_per_million",ascending=False).head(10)

# %%
highest_cases_df
# Out:
#           location  cases_per_million
# 155          Qatar       41375.743650
# 14         Bahrain       30818.361490
# 147         Panama       21805.112117
# 40           Chile       21695.671982
# 162     San Marino       21657.139490
# 9            Aruba       20708.839893
# 105         Kuwait       20249.789079
# 150           Peru       20121.318048
# 27          Brazil       18808.224105
# 199  United States       18472.377957

# %%
highest_cases_df=combined_df[["location","tests_per_million"]].sort_values("tests_per_million",ascending=False).head(10)

# %%
highest_cases_df
# Out:
#                  location  tests_per_million
# 197  United Arab Emirates      725696.635121
# 14                Bahrain      657527.137965
# 115            Luxembourg      616349.508607
# 122                 Malta      427004.183096
# 53                Denmark      422621.755488
# 96                 Israel      271962.665303
# 89                Iceland      260304.761905
# 157                Russia      254750.159763
# 199         United States      253467.507769
# 10              Australia      245326.517406

# %%
highest_cases_df=combined_df[["location","deaths_per_million"]].sort_values("deaths_per_million",ascending=False).head(10)

# %%
highest_cases_df
# Out:
#            location  deaths_per_million
# 162      San Marino         1237.550828
# 150            Peru          887.393445
# 18          Belgium          854.040375
# 3           Andorra          685.950948
# 177           Spain          624.406705
# 198  United Kingdom          611.525168
# 40            Chile          593.423100
# 97            Italy          587.097697
# 27           Brazil          582.331314
# 182          Sweden          576.279276
